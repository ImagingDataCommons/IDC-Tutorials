# %% [markdown]
# <a href="https://colab.research.google.com/github/ImagingDataCommons/IDC-Examples/blob/master/notebooks/clinical_data_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [WIP] IDC clinical data exploration
#
# The goal of this notebook is to introduce the users of NCI Imaging Data Commons (IDC) to the organization of clinical data BigQuery tables that accompany some of the IDC imaging data.
#
# [NCI Imaging Data Commons (IDC)](https://imaging.datacommons.cancer.gov) is a cloud-based repository of publicly available cancer imaging data co-located with the analysis and exploration tools and resources. IDC is a node within the broader [NCI Cancer Research Data Commons (CRDC)](https://datacommons.cancer.gov/) infrastructure that provides secure access to a large, comprehensive, and expanding collection of cancer research data.
#
# If you are not familiar with IDC, we recommend you first take a look at the [Getting started](https://github.com/ImagingDataCommons/IDC-Examples/blob/master/notebooks/getting_started.ipynb) notebook that is intended to serve as the introduction into working with IDC programmatically.
#
# If you have any questions about this tutorial, please post your questions on the [IDC user forum](https://discourse.canceridc.dev/) (preferred) or email IDC support at support@canceridc.dev!
#
# Authored by Andrey Fedorov and George White
#
# Prepared: July 2022
#
# Updated: Sept 2022

# %% [markdown]
# # Prerequisites
#
# In order to be able to run the cells in this notebook, you must complete the prerequisites to set up your Google Cloud Platform account, as discussed here: https://learn.canceridc.dev/introduction/getting-started-with-gcp.
#
# Once you completed the prerequisites, insert your Google Cloud Platform project ID in the cell below in place of `REPLACE_ME_WITH_YOUR_PROJECT_ID`.

# %%
# initialize this variable with your Google Cloud Project ID!
my_ProjectID = "idc-sandbox-000"

import os
os.environ["GCP_PROJECT_ID"] = my_ProjectID

# !gcloud config set project $GCP_PROJECT_ID
# Out:
# Updated property [core/project].

# %% [markdown]
# In the following cell you will be asked to authorize Google Collaboratory to act on your behalf. In order to proceed with the following cells you must allow this.

# %%
# you will need to authenticate with your Google ID to do anything meaningful with IDC
from google.colab import auth
auth.authenticate_user()

# %% [markdown]
# # Clinical data - background
#
# By clinical data we refer to the broad spectrum of image-related data that may accompany images. Such data may include demographics of the patients, observations related to their clinical history (therapies, diagnoses, findings), lab tests, surgeries.
#
# Clinical data is often critical in understanding imaging data, and is essential for the development and validation of imaging biomarkers. However, such data is most often stored in spreadsheets that follow conventions specific to the site that collected the data, may not be accompanied by the dictionary defining the terms used in describing clinical data, and is rarely harmonized. As an example, you can consider examing the clinical data that accompanies the [ACRIN 6698 collection](https://wiki.cancerimagingarchive.net/pages/viewpage.action?pageId=50135447) curated by The Cancer Imaging Archive (TCIA). File named "Full Ancillary Patient Information file.xlsx" linked from the collection page contains two sheets, one of which is the dictionary, and the othe one contains per-patient data with the columns defined by the dictionary.
#
# Not only the terms used in the clinical data accompanying individual collection are not harmonized, but the format of the spreadsheets is also collection-specific. In order to search and navigate clinical data, one has to parse those collection specific tables, and there is no interface to support searching across collections.
#
# With the release v11 of IDC, we make the attempt to lower the barriers for accessing clinical data accompanying IDC imaging collections. We parse collection-specific tables, and organize the underlying data into BigQuery tables that can be accessed using standard SQL queries. You can also see the summary of clinical data available for IDC collections in [this dashboard](https://datastudio.google.com/u/0/reporting/04cf5976-4ea0-4fee-a749-8bfd162f2e87/page/p_s7mk6eybqc).
#
# At the completion of this tutorial you will learn how IDC clinical data is organized, and how to write queries to interrogate this data.

# %% [markdown]
# # Overall organization of clinical data in IDC
#
# Clinical data accompanying imaging collections is organized into collection-specific tables in the `idc_current_clinical` BigQuery dataset (in order to locate this dataset, you will need to navigate to the [BigQuery console](https://console.cloud.google.com/bigquery), and locate `idc_current_clinical` under the `bigquery-public-data` project, which you should have added in the prerequisites mentioned earlier.
#
# Those per-collection clinical tables
#
# The only column that is initialized consistently across those collection-specific tables is `dicom_patient_id`, which corresponds to the `PatientID` column in the `dicom_all` table.
#
# Note that some imaging collections do not have any clinical data at all, while others may have multiple tables containing various types of clinical data.
#
# `column_metadata` can be used as a "key" for identifying information of interest in clinical metadata. It contains information about the columns across all of the collections for which we have clinical data.

# %% [markdown]
# First, instantiate the query client, which can next be configured to run the query.

# %%
# python API is the most flexible way to query IDC BigQuery metadata tables
from google.cloud import bigquery
bq_client = bigquery.Client(my_ProjectID)

# %%
selection_query = """
SELECT *
FROM bigquery-public-data.idc_v11_clinical.column_metadata
"""

selection_result = bq_client.query(selection_query)
column_metadata_df = selection_result.result().to_dataframe()

# %%
column_metadata_df.columns
# Out:
# Index(['collection_id', 'case_col', 'table_name', 'column', 'column_label',
#        'data_type', 'original_column_headers', 'values', 'files',
#        'sheet_names', 'batch', 'column_numbers'],
#       dtype='object')

# %% [markdown]
# The most important columns in this table are the following:
# * `column`: name of the column in a collection-specific clinical metadata table; note that for some of the collections this name may not contain any human readable information, and may instead be a coded value
# * `column_label`: for some collections it may contain a description for a column name that otherwise may not be human readable. For other collections it is the original name of the column in the source Excel file
# * `collection_id` and `table_name` identify the collection the specific column corresponds to, and the name of the clinical data table where this column is present.

# %% [markdown]
# ## Exploring clinical data: discovery mode
#
# Sometime you may want to find whether specific clinical attribute is available for the imaging data you can find in IDC.
#
# Here's an example of the columns that correspond to the clinical metadata in one of the ACRIN collections, where `column` is not particularly helpful, but `column_label` provides human readable information to allow interpretation of the column.

# %%
column_metadata_df[column_metadata_df["collection_id"] == "acrin_nsclc_fdg_pet"][:5]
# Out:
#            collection_id  case_col  \
# 750  acrin_nsclc_fdg_pet     False
# 751  acrin_nsclc_fdg_pet     False
# 752  acrin_nsclc_fdg_pet     False
# 753  acrin_nsclc_fdg_pet     False
# 754  acrin_nsclc_fdg_pet     False
#
#                                             table_name column  \
# 750  bigquery-public-data.idc_v11_clinical.acrin_ns...   a0e9
# 751  bigquery-public-data.idc_v11_clinical.acrin_ns...  a0e10
# 752  bigquery-public-data.idc_v11_clinical.acrin_ns...  a0e11
# 753  bigquery-public-data.idc_v11_clinical.acrin_ns...  a0e12
# 754  bigquery-public-data.idc_v11_clinical.acrin_ns...  a0e14
#
#                        column_label data_type original_column_headers  \
# 750                 ETHNIC CATEGORY      List    [['a0e9'], ['a0e9']]
# 751                            RACE      List  [['A0E10'], ['A0E10']]
# 752                          GENDER      List  [['a0e11'], ['a0e11']]
# 753            COUNTRY OF RESIDENCE      List  [['a0e12'], ['a0e12']]
# 754  PARTICIPANT'S INSURANCE STATUS      List  [['a0e14'], ['a0e14']]
#
#                                                 values  \
# 750  [{'option_code': '1', 'option_description': 'H...
# 751  [{'option_code': '1', 'option_description': 'A...
# 752  [{'option_code': '1', 'option_description': 'M...
# 753  [{'option_code': '1', 'option_description': 'U...
# 754  [{'option_code': '3', 'option_description': 'M...
#
#                                                  files sheet_names   batch  \
# 750  [ACRIN 6668 NSCLC FDG PET - ACRIN Data TCIA An...          []  [0, 1]
# 751  [ACRIN 6668 NSCLC FDG PET - ACRIN Data TCIA An...          []  [0, 1]
# 752  [ACRIN 6668 NSCLC FDG PET - ACRIN Data TCIA An...          []  [0, 1]
# 753  [ACRIN 6668 NSCLC FDG PET - ACRIN Data TCIA An...          []  [0, 1]
# 754  [ACRIN 6668 NSCLC FDG PET - ACRIN Data TCIA An...          []  [0, 1]
#
#     column_numbers
# 750         [8, 8]
# 751         [9, 9]
# 752       [10, 10]
# 753       [11, 11]
# 754       [12, 12]

# %% [markdown]
# For some columns, the values come from a defined set. In the example above, we can, for example, examine the values assigned to encode patient race.

# %%
race_values = column_metadata_df[(column_metadata_df["collection_id"] == "acrin_nsclc_fdg_pet") & (column_metadata_df["column_label"] == "RACE")]["values"]

race_values.tolist()
# Out:
# [[{'option_code': '1',
#    'option_description': 'American Indian or Alaska Native'},
#   {'option_code': '2', 'option_description': 'Asian'},
#   {'option_code': '3', 'option_description': 'Black or African American'},
#   {'option_code': '4',
#    'option_description': 'Native Hawaiian or other Pacific Islander'},
#   {'option_code': '5', 'option_description': 'White'},
#   {'option_code': '6', 'option_description': 'More than one race'},
#   {'option_code': '9', 'option_description': 'Unknown'}]]

# %% [markdown]
# On the other hand, if we look at the metadata available for the `c4kc_kits` collection, `column_label` and `column` are identical.

# %%
column_metadata_df[column_metadata_df["collection_id"] == "c4kc_kits"][:3]
# Out:
#      collection_id  case_col  \
# 1186     c4kc_kits     False
# 1187     c4kc_kits     False
# 1483     c4kc_kits      True
#
#                                              table_name  \
# 1186  bigquery-public-data.idc_v11_clinical.c4kc_kit...
# 1187  bigquery-public-data.idc_v11_clinical.c4kc_kit...
# 1483  bigquery-public-data.idc_v11_clinical.c4kc_kit...
#
#                         column              column_label data_type  \
# 1186           hospitalization           hospitalization    String
# 1187  tumor_histologic_subtype  tumor_histologic_subtype    String
# 1483                patient_id                patient_id    String
#
#              original_column_headers  \
# 1186           [['hospitalization']]
# 1187  [['tumor_histologic_subtype']]
# 1483                [['patient_id']]
#
#                                                  values  \
# 1186  [{'option_code': '0', 'option_description': No...
# 1187  [{'option_code': 'angiomyolipoma', 'option_des...
# 1483                                                 []
#
#                                         files sheet_names batch column_numbers
# 1186  [C4KC KiTS_Clinical Data_Version 1.csv]          []   [0]           [31]
# 1187  [C4KC KiTS_Clinical Data_Version 1.csv]          []   [0]           [39]
# 1483  [C4KC KiTS_Clinical Data_Version 1.csv]          []   [0]            [0]

# %% [markdown]
# **As a general rule of thumb**:
# * when selecting specific columns from clinical tables, use `column`
# * when searching for concepts of interest in `column_metadata`, use `column_label`
#
# Now, let's look at the distinct values of `column_label` (which in the general case will be either more descriptive, or identical to `column`).

# %%
import pandas as pd

pd.DataFrame({"column_label":column_metadata_df["column_label"].unique()})
# Out:
#                                            column_label
# 0        T0 (baseline) MRI study included in collection
# 1        T1 (early-Tx) MRI study included in collection
# 2     T2 (inter-regimen) MRI study included in colle...
# 3     T3 (pre-surgery) MRI study included in collection
# 4     Patient included in the BMMR2 challenge traini...
# ...                                                 ...
# 4010                                                 cn
# 4011                      Data receipt (from base date)
# 4012              Data Entry Date (Days from base date)
# 4013                        idc_provenance_source_batch
# 4014                    idc_provenance_dicom_patient_id
#
# [4015 rows x 1 columns]

# %% [markdown]
# Let's say we want to know which of the cases have information related to therapy. We can search column metadata for the presence of word "therapy" (since the terms in clinical data are not harmonized, we need to account for the variability in capitalization).

# %%
column_metadata_df[column_metadata_df["column_label"].str.contains("[tT]herapy", na=False)][["column_label", "collection_id", "values"]]
# Out:
#                                   column_label            collection_id  \
# 1193             radiotherapy_total_treat_time  head_neck_radiomics_hn1
# 1197                 CCRT Chemotherapy Regimen                    hnscc
# 1246   OnStudy Therapy Surgery Procedure Title                rembrandt
# 1604                    Induction Chemotherapy                    hnscc
# 1754          OnStudy Therapy Chemo Agent Name                rembrandt
# ...                                        ...                      ...
# 5353             Other.anticoagulation.therapy          covid_19_ny_sbu
# 5355                      Chemotherapy Regimen                    hnscc
# 5356                   Chemotherapy Medication            hnscc_3dct_rt
# 5364            OnStudy Therapy Radiation Type                rembrandt
# 5365           OnStudy Therapy Surgery Outcome                rembrandt
#
#                                                  values
# 1193  [{'option_code': '31', 'option_description': N...
# 1197  [{'option_code': 'Carbolatin weekly', 'option_...
# 1246  [{'option_code': ' --', 'option_description': ...
# 1604                                                 []
# 1754                                                 []
# ...                                                 ...
# 5353  [{'option_code': 'apixaban', 'option_descripti...
# 5355  [{'option_code': 'Carbolatin weekly', 'option_...
# 5356  [{'option_code': 'Carboplatin', 'option_descri...
# 5364  [{'option_code': ' --', 'option_description': ...
# 5365  [{'option_code': ' --', 'option_description': ...
#
# [69 rows x 3 columns]

# %% [markdown]
# We observe that there are several collections that contain column named "Chemotherapy". Let's filter these values further, in order to identify subjects that underwent chemotherapy.

# %%
column_metadata_df[column_metadata_df["column_label"].str.contains("[Cc]hemotherapy", na=False)][[ "collection_id", "table_name", "column", "column_label","values"]]
# Out:
#                 collection_id  \
# 1197                    hnscc
# 1604                    hnscc
# 4085            opc_radiomics
# 4441  head_neck_radiomics_hn1
# 4449                    hnscc
# 4476      nsclc_radiogenomics
# 4977             hcc_tace_seg
# 5355                    hnscc
# 5356            hnscc_3dct_rt
#
#                                              table_name  \
# 1197  bigquery-public-data.idc_v11_clinical.hnscc_cl...
# 1604  bigquery-public-data.idc_v11_clinical.hnscc_cl...
# 4085  bigquery-public-data.idc_v11_clinical.opc_radi...
# 4441  bigquery-public-data.idc_v11_clinical.head_nec...
# 4449  bigquery-public-data.idc_v11_clinical.hnscc_cl...
# 4476  bigquery-public-data.idc_v11_clinical.nsclc_ra...
# 4977  bigquery-public-data.idc_v11_clinical.hcc_tace...
# 5355  bigquery-public-data.idc_v11_clinical.hnscc_cl...
# 5356  bigquery-public-data.idc_v11_clinical.hnscc_3d...
#
#                            column                           column_label  \
# 1197    ccrt_chemotherapy_regimen              CCRT Chemotherapy Regimen
# 1604       induction_chemotherapy                 Induction Chemotherapy
# 4085                chemotherapy_                          Chemotherapy
# 4441           chemotherapy_given                     chemotherapy_given
# 4449  platinum_based_chemotherapy            Platinum-based chemotherapy
# 4476                 chemotherapy                           Chemotherapy
# 4977                 chemotherapy  chemotherapy used for TACE procedure
# 5355         chemotherapy_regimen                   Chemotherapy Regimen
# 5356      chemotherapy_medication                Chemotherapy Medication
#
#                                                  values
# 1197  [{'option_code': 'Carbolatin weekly', 'option_...
# 1604                                                 []
# 4085  [{'option_code': 'Yes', 'option_description': ...
# 4441  [{'option_code': 'concomitant', 'option_descri...
# 4449  [{'option_code': 'No', 'option_description': N...
# 4476  [{'option_code': 'No', 'option_description': N...
# 4977  [{'option_code': 'Cisplastin', 'option_descrip...
# 5355  [{'option_code': 'Carbolatin weekly', 'option_...
# 5356  [{'option_code': 'Carboplatin', 'option_descri...

# %% [markdown]
# From the table above we can observe that:
#
# 1. There are 5 collections that have clinical metadata related to chemotherapy regimen of the subject;
#
# 2. There are no value sets assigned for the column `induction_chemotherapy` in the table `hnscc_clinical`. Value sets may be missing if the dictionary is not provided, or if there are a large number (>20) distinct values of the column in the table. In such cases one can check the distinct values of the column by querying the table directly.
#
# Looking at the value sets for the collections/columns that have those, we can observe that subjects that had any chemotherapy could be selected as follows for the respective collections (non-exhaustive list):
# * `head_neck_radiomics_hn1`: subjects that have value other than `none` in table `head_neck_radiomics_hn1_clinical` column `chemotherapy_given`
# * `hnscc`: subjects that have value other than `No` in table `hnscc_clinical` column `chemotherapy_regime`
# * `hnscc_3dct_rt`: subjects that have value other than `None` in table `hnscc_3dct_rt_demographics` column `chemotherapy_medication`
# * `nsclc_radiogenomics`: subjects that have value `Yes` in table `nsclc_radiogenomics_clinical` column `chemotherapy`
# * `hcc_tace_seg` column `chemotherapy` in the `hcc_tace_seg_clinical` table
#
# Before we select subjects that meet the criteria defined above, let's confirm  the values encountered in table `hcc_tace_seg_clinical` column `chemotherapy` match the value set in the `column_metadata` table.
#
# The query below will select the distinct values encountered in the `chemotherapy` column of the `hcc_tace_seg_clinical` table.

# %%
selection_query = """
SELECT DISTINCT(chemotherapy)
FROM bigquery-public-data.idc_v11_clinical.hcc_tace_seg_clinical
"""

selection_result = bq_client.query(selection_query)
hcc_tace_seg_clinical_df = selection_result.result().to_dataframe()
hcc_tace_seg_clinical_df
# Out:
#                           chemotherapy
# 0  Cisplatin, doxorubicin, Mitomycin-C
# 1                                 None
# 2                 doxorubicin LC beads
# 3                           Cisplastin
# 4               Cisplatin, Mitomycin-C

# %% [markdown]
# The following cell will get the dictionary for that column from the `column_metadata` table.

# %%
chemotherapy_medication_values = \
  column_metadata_df[(column_metadata_df["table_name"] == "bigquery-public-data.idc_v11_clinical.hcc_tace_seg_clinical") \
                     & (column_metadata_df["column"] == "chemotherapy")]["values"]

print(chemotherapy_medication_values.tolist())
# Out:
# [[{'option_code': 'Cisplastin', 'option_description': None}, {'option_code': 'Cisplatin, Mitomycin-C', 'option_description': None}, {'option_code': 'Cisplatin, doxorubicin, Mitomycin-C', 'option_description': None}, {'option_code': 'doxorubicin LC beads', 'option_description': None}, {'option_code': 'null', 'option_description': None}]]

# %% [markdown]
# Next we can examine the data to see what therapy individual patients had.

# %%
selection_query = """
SELECT DISTINCT(dicom_patient_id), chemotherapy
FROM bigquery-public-data.idc_v11_clinical.hcc_tace_seg_clinical
WHERE chemotherapy <> "null"
"""

selection_result = bq_client.query(selection_query)
hcc_tace_seg_clinical_df = selection_result.result().to_dataframe()
hcc_tace_seg_clinical_df
# Out:
#    dicom_patient_id                         chemotherapy
# 0           HCC_001  Cisplatin, doxorubicin, Mitomycin-C
# 1           HCC_006  Cisplatin, doxorubicin, Mitomycin-C
# 2           HCC_010  Cisplatin, doxorubicin, Mitomycin-C
# 3           HCC_017  Cisplatin, doxorubicin, Mitomycin-C
# 4           HCC_026  Cisplatin, doxorubicin, Mitomycin-C
# ..              ...                                  ...
# 83          HCC_050  Cisplatin, doxorubicin, Mitomycin-C
# 84          HCC_065  Cisplatin, doxorubicin, Mitomycin-C
# 85          HCC_073                 doxorubicin LC beads
# 86          HCC_085                 doxorubicin LC beads
# 87          HCC_090                 doxorubicin LC beads
#
# [88 rows x 2 columns]

# %% [markdown]
# `dicom_patient_id` is the key to connect clinical data and imaging data. Let's see what imaging studies we have for patient `HCC_101` that was treated with 	doxorubicin LC beads. Along the way we can also generate viewer URLs to conveniently examine the images.

# %%
# %%bigquery --project=idc-sandbox-000
#
# SELECT
#   StudyInstanceUID,
#   STRING_AGG(DISTINCT(Modality)) AS modalities,
#   STRING_AGG(DISTINCT(collection_id)) AS collection_id,
#   STRING_AGG(DISTINCT(Access)) AS access,
#   COUNT(DISTINCT(SeriesInstanceUID)) AS num_series,
#   # TODO: use production URL once the release is out!
#   #ANY_VALUE(CONCAT("https://viewer.imaging.datacommons.cancer.gov/viewer/", StudyInstanceUID)) as viewer_url
#   ANY_VALUE(CONCAT("https://testing-viewer.canceridc.dev/viewer/", StudyInstanceUID)) as viewer_url
# FROM bigquery-public-data.idc_v11.dicom_all
# WHERE PatientID = "HCC_103"
# GROUP BY StudyInstanceUID
# Out:
#                                     StudyInstanceUID modalities collection_id  \
# 0  1.3.6.1.4.1.14519.5.2.1.1706.8374.304819071818...     CT,SEG  hcc_tace_seg
# 1  1.3.6.1.4.1.14519.5.2.1.1706.8374.121752675166...         CT  hcc_tace_seg
#
#    access  num_series                                         viewer_url
# 0  Public           3  https://testing-viewer.canceridc.dev/viewer/1....
# 1  Public           2  https://testing-viewer.canceridc.dev/viewer/1....

# %% [markdown]
# ## Exploring clinical data: collection-focused exploration
#
# Let's see which of the collections in IDC have clinical data in BigQuery:

# %%
column_metadata_df["collection_id"].unique().tolist()
# Out:
# ['acrin_6698',
#  'acrin_flt_breast',
#  'acrin_fmiso_brain',
#  'acrin_hnscc_fdg_pet_ct',
#  'acrin_nsclc_fdg_pet',
#  'b_mode_and_ceus_liver',
#  'breast_diagnosis',
#  'breast_mri_nact_pilot',
#  'c4kc_kits',
#  'covid_19_ar',
#  'head_neck_pet_ct',
#  'head_neck_radiomics_hn1',
#  'hnscc',
#  'hnscc_3dct_rt',
#  'ispy2',
#  'lidc_idri',
#  'lung_pet_ct_dx',
#  'midrc_ricord_1a',
#  'midrc_ricord_1b',
#  'nsclc_radiomics_genomics',
#  'nsclc_radiomics_interobserver1',
#  'opc_radiomics',
#  'qin_headneck',
#  'rembrandt',
#  'soft_tissue_sarcoma',
#  'cptac_brca',
#  'cptac_ccrcc',
#  'cptac_coad',
#  'cptac_gbm',
#  'cptac_hnscc',
#  'cptac_lscc',
#  'cptac_luad',
#  'cptac_pda',
#  'cptac_ucec',
#  'tcga_acc',
#  'tcga_blca',
#  'tcga_brca',
#  'tcga_cesc',
#  'tcga_chol',
#  'tcga_coad',
#  'tcga_dlbc',
#  'tcga_esca',
#  'tcga_hnsc',
#  'tcga_kich',
#  'tcga_kirc',
#  'tcga_kirp',
#  'tcga_lgg',
#  'tcga_lihc',
#  'tcga_luad',
#  'tcga_lusc',
#  'tcga_meso',
#  'tcga_ov',
#  'tcga_paad',
#  'tcga_pcpg',
#  'tcga_prad',
#  'tcga_read',
#  'tcga_sarc',
#  'tcga_skcm',
#  'tcga_stad',
#  'tcga_tgct',
#  'tcga_thca',
#  'tcga_thym',
#  'tcga_ucec',
#  'tcga_ucs',
#  'tcga_uvm',
#  'cmmd',
#  'covid_19_ny_sbu',
#  'hcc_tace_seg',
#  'ispy1',
#  'midrc_ricord_1c',
#  'nsclc_radiomics',
#  'nsclc_radiogenomics',
#  'prostate_diagnosis',
#  'qin_breast',
#  'spie_aapm_lung_ct_challenge',
#  'cptac_ov',
#  'tcga_gbm',
#  'lung_fused_ct_pathology']

# %% [markdown]
# If you are interested in what clinical data is available for the specific collection, you can select only the rows corresponding to that collection in the `column_metadata` table. Here we select a subset of columns to improve readability of the dataframe.
#
# Note that for some collections, clinical data sheets are accompanied by dictionaries, which formalize the values encountered. Examples of such collections are [ISPY1](https://wiki.cancerimagingarchive.net/display/Public/ISPY1) or ACRIN trials.
#
# For many other collections there are no such dictionaries available. In those situations, the values you will see in the `values` columns have been derived by examining the distinct values encountered in the clinical data sheets.

# %%
ispy1_clinical_df = column_metadata_df[column_metadata_df["collection_id"] == "acrin_6698"] #[["collection_id", "table_name", "column", "column_label", "data_type", "values"]]

ispy1_clinical_df
# Out:
#      collection_id  case_col  \
# 0       acrin_6698     False
# 1       acrin_6698     False
# 2       acrin_6698     False
# 3       acrin_6698     False
# 4       acrin_6698     False
# 5       acrin_6698     False
# 6       acrin_6698     False
# 7       acrin_6698     False
# 8       acrin_6698     False
# 9       acrin_6698     False
# 10      acrin_6698     False
# 11      acrin_6698     False
# 12      acrin_6698     False
# 13      acrin_6698     False
# 14      acrin_6698     False
# 15      acrin_6698     False
# 16      acrin_6698     False
# 17      acrin_6698     False
# 18      acrin_6698     False
# 19      acrin_6698     False
# 20      acrin_6698     False
# 21      acrin_6698     False
# 22      acrin_6698     False
# 23      acrin_6698     False
# 24      acrin_6698     False
# 1458    acrin_6698      True
# 1459    acrin_6698     False
# 1460    acrin_6698     False
# 1461    acrin_6698     False
# 3949    acrin_6698     False
# 9611    acrin_6698     False
# 9692    acrin_6698     False
#
#                                              table_name                column  \
# 0     bigquery-public-data.idc_v11_clinical.acrin_66...                    t0
# 1     bigquery-public-data.idc_v11_clinical.acrin_66...                    t1
# 2     bigquery-public-data.idc_v11_clinical.acrin_66...                    t2
# 3     bigquery-public-data.idc_v11_clinical.acrin_66...                    t3
# 4     bigquery-public-data.idc_v11_clinical.acrin_66...           bmmr2_train
# 5     bigquery-public-data.idc_v11_clinical.acrin_66...            bmmr2_test
# 6     bigquery-public-data.idc_v11_clinical.acrin_66...        primary_aim_t0
# 7     bigquery-public-data.idc_v11_clinical.acrin_66...        primary_aim_t1
# 8     bigquery-public-data.idc_v11_clinical.acrin_66...        primary_aim_t2
# 9     bigquery-public-data.idc_v11_clinical.acrin_66...        primary_aim_t3
# 10    bigquery-public-data.idc_v11_clinical.acrin_66...           test_retest
# 11    bigquery-public-data.idc_v11_clinical.acrin_66...       qc_pass_fail_t0
# 12    bigquery-public-data.idc_v11_clinical.acrin_66...       qc_pass_fail_t1
# 13    bigquery-public-data.idc_v11_clinical.acrin_66...       qc_pass_fail_t2
# 14    bigquery-public-data.idc_v11_clinical.acrin_66...       qc_pass_fail_t3
# 15    bigquery-public-data.idc_v11_clinical.acrin_66...  qc_roi_confidence_t0
# 16    bigquery-public-data.idc_v11_clinical.acrin_66...  qc_roi_confidence_t1
# 17    bigquery-public-data.idc_v11_clinical.acrin_66...  qc_roi_confidence_t2
# 18    bigquery-public-data.idc_v11_clinical.acrin_66...  qc_roi_confidence_t3
# 19    bigquery-public-data.idc_v11_clinical.acrin_66...       analysis_cohort
# 20    bigquery-public-data.idc_v11_clinical.acrin_66...                  race
# 21    bigquery-public-data.idc_v11_clinical.acrin_66...                 ltype
# 22    bigquery-public-data.idc_v11_clinical.acrin_66...               hrher4g
# 23    bigquery-public-data.idc_v11_clinical.acrin_66...              sbrgrade
# 24    bigquery-public-data.idc_v11_clinical.acrin_66...                   pcr
# 1458  bigquery-public-data.idc_v11_clinical.acrin_66...   i_spy_2_research_id
# 1459  bigquery-public-data.idc_v11_clinical.acrin_66...       tcia_patient_id
# 1460  bigquery-public-data.idc_v11_clinical.acrin_66...                   age
# 1461  bigquery-public-data.idc_v11_clinical.acrin_66...                  mrld
# 3949  bigquery-public-data.idc_v11_clinical.acrin_66...            eligigible
# 9611  bigquery-public-data.idc_v11_clinical.acrin_66...          source_batch
# 9692  bigquery-public-data.idc_v11_clinical.acrin_66...      dicom_patient_id
#
#                                            column_label data_type  \
# 0        T0 (baseline) MRI study included in collection     int64
# 1        T1 (early-Tx) MRI study included in collection     int64
# 2     T2 (inter-regimen) MRI study included in colle...     int64
# 3     T3 (pre-surgery) MRI study included in collection     int64
# 4     Patient included in the BMMR2 challenge traini...     int64
# 5     Patient included in the BMMR2 challenge test c...     int64
# 6     T0 MRI study included in the ACRIN-6698 primar...     int64
# 7     T1 MRI study included in the ACRIN-6698 primar...     int64
# 8     T2 MRI study included in the ACRIN-6698 primar...     int64
# 9     T3 MRI study included in the ACRIN-6698 primar...     int64
# 10    Study time point that includes test/retest DWI...    String
# 11               T0 MRI DWI Quality control assessment:    String
# 12               T0 MRI DWI Quality control assessment:    String
# 13               T0 MRI DWI Quality control assessment:    String
# 14               T0 MRI DWI Quality control assessment:    String
# 15    T0 quality control confidence level for whole-...    String
# 16    T1 quality control confidence level for whole-...    String
# 17    T2 quality control confidence level for whole-...    String
# 18    T3 quality control confidence level for whole-...    String
# 19           Patient in primary analysis cohort (n=242)     int64
# 20                                        Patient race:    String
# 21                                   Index lesion type:    String
# 22               Hormone receptor (HR) and HER2 status:    String
# 23                                         Tumor grade:    String
# 24        Pathologic complete response (pCR) at surgery    String
# 1458      Double-blinded patient ID number from I-SPY 2    String
# 1459  Patient identification string in TCIA collecti...    String
# 1460                         Age in years at enrollment    String
# 1461  MRI measured longest diameter (cm) at baseline...   float64
# 3949                                         eligigible     int64
# 9611                        idc_provenance_source_batch     int64
# 9692                    idc_provenance_dicom_patient_id    String
#
#                     original_column_headers  \
# 0                                  [['T0']]
# 1                                  [['T1']]
# 2                                  [['T2']]
# 3                                  [['T3']]
# 4                         [['BMMR2_TRAIN']]
# 5                          [['BMMR2_TEST']]
# 6                      [['PRIMARY_AIM_T0']]
# 7                      [['PRIMARY_AIM_T1']]
# 8                      [['PRIMARY_AIM_T2']]
# 9                      [['PRIMARY_AIM_T3']]
# 10                        [['TEST_RETEST']]
# 11                    [['QC_PASS_FAIL_T0']]
# 12                    [['QC_PASS_FAIL_T1']]
# 13                    [['QC_PASS_FAIL_T2']]
# 14                    [['QC_PASS_FAIL_T3']]
# 15               [['QC_ROI_CONFIDENCE_T0']]
# 16               [['QC_ROI_CONFIDENCE_T1']]
# 17               [['QC_ROI_CONFIDENCE_T2']]
# 18               [['QC_ROI_CONFIDENCE_T3']]
# 19                    [['analysis cohort']]
# 20                               [['race']]
# 21                              [['Ltype']]
# 22                            [['hrher4g']]
# 23                           [['SBRgrade']]
# 24                                [['pcr']]
# 1458              [['I-SPY 2 Research ID']]
# 1459                  [['TCIA PATIENT ID']]
# 1460                              [['age']]
# 1461                             [['MRLD']]
# 3949                       [['eligigible']]
# 9611      [['idc_provenance_source_batch']]
# 9692  [['idc_provenance_dicom_patient_id']]
#
#                                                  values  \
# 0     [{'option_code': '0', 'option_description': ' ...
# 1     [{'option_code': '0', 'option_description': ' ...
# 2     [{'option_code': '0', 'option_description': ' ...
# 3     [{'option_code': '0', 'option_description': ' ...
# 4     [{'option_code': '0', 'option_description': ' ...
# 5     [{'option_code': '0', 'option_description': ' ...
# 6     [{'option_code': '0', 'option_description': ' ...
# 7     [{'option_code': '0', 'option_description': ' ...
# 8     [{'option_code': '0', 'option_description': ' ...
# 9     [{'option_code': '0', 'option_description': ' ...
# 10    [{'option_code': 'T0', 'option_description': N...
# 11    [{'option_code': 'PASS', 'option_description':...
# 12    [{'option_code': 'PASS', 'option_description':...
# 13    [{'option_code': 'PASS', 'option_description':...
# 14    [{'option_code': 'PASS', 'option_description':...
# 15    [{'option_code': 'HIGH', 'option_description':...
# 16    [{'option_code': 'HIGH', 'option_description':...
# 17    [{'option_code': 'HIGH', 'option_description':...
# 18    [{'option_code': 'HIGH', 'option_description':...
# 19    [{'option_code': '0', 'option_description': ' ...
# 20    [{'option_code': 'White', 'option_description'...
# 21    [{'option_code': 'Single mass', 'option_descri...
# 22    [{'option_code': 'HR + / HER2 +', 'option_desc...
# 23    [{'option_code': 'I (Low)', 'option_descriptio...
# 24    [{'option_code': 'non-pCR', 'option_descriptio...
# 1458                                                 []
# 1459                                                 []
# 1460                                                 []
# 1461                                                 []
# 3949  [{'option_code': '0', 'option_description': No...
# 9611  [{'option_code': '0', 'option_description': No...
# 9692                                                 []
#
#                                                   files  \
# 0     [Full Collection Ancillary Patient Information...
# 1     [Full Collection Ancillary Patient Information...
# 2     [Full Collection Ancillary Patient Information...
# 3     [Full Collection Ancillary Patient Information...
# 4     [Full Collection Ancillary Patient Information...
# 5     [Full Collection Ancillary Patient Information...
# 6     [Full Collection Ancillary Patient Information...
# 7     [Full Collection Ancillary Patient Information...
# 8     [Full Collection Ancillary Patient Information...
# 9     [Full Collection Ancillary Patient Information...
# 10    [Full Collection Ancillary Patient Information...
# 11    [Full Collection Ancillary Patient Information...
# 12    [Full Collection Ancillary Patient Information...
# 13    [Full Collection Ancillary Patient Information...
# 14    [Full Collection Ancillary Patient Information...
# 15    [Full Collection Ancillary Patient Information...
# 16    [Full Collection Ancillary Patient Information...
# 17    [Full Collection Ancillary Patient Information...
# 18    [Full Collection Ancillary Patient Information...
# 19    [Full Collection Ancillary Patient Information...
# 20    [Full Collection Ancillary Patient Information...
# 21    [Full Collection Ancillary Patient Information...
# 22    [Full Collection Ancillary Patient Information...
# 23    [Full Collection Ancillary Patient Information...
# 24    [Full Collection Ancillary Patient Information...
# 1458  [Full Collection Ancillary Patient Information...
# 1459  [Full Collection Ancillary Patient Information...
# 1460  [Full Collection Ancillary Patient Information...
# 1461  [Full Collection Ancillary Patient Information...
# 3949  [Full Collection Ancillary Patient Information...
# 9611                                                 []
# 9692                                                 []
#
#                             sheet_names batch column_numbers
# 0     [ACRIN_6698_Patient_Cohorts_Clin]   [0]            [2]
# 1     [ACRIN_6698_Patient_Cohorts_Clin]   [0]            [3]
# 2     [ACRIN_6698_Patient_Cohorts_Clin]   [0]            [4]
# 3     [ACRIN_6698_Patient_Cohorts_Clin]   [0]            [5]
# 4     [ACRIN_6698_Patient_Cohorts_Clin]   [0]            [6]
# 5     [ACRIN_6698_Patient_Cohorts_Clin]   [0]            [7]
# 6     [ACRIN_6698_Patient_Cohorts_Clin]   [0]            [8]
# 7     [ACRIN_6698_Patient_Cohorts_Clin]   [0]            [9]
# 8     [ACRIN_6698_Patient_Cohorts_Clin]   [0]           [10]
# 9     [ACRIN_6698_Patient_Cohorts_Clin]   [0]           [11]
# 10    [ACRIN_6698_Patient_Cohorts_Clin]   [0]           [12]
# 11    [ACRIN_6698_Patient_Cohorts_Clin]   [0]           [13]
# 12    [ACRIN_6698_Patient_Cohorts_Clin]   [0]           [14]
# 13    [ACRIN_6698_Patient_Cohorts_Clin]   [0]           [15]
# 14    [ACRIN_6698_Patient_Cohorts_Clin]   [0]           [16]
# 15    [ACRIN_6698_Patient_Cohorts_Clin]   [0]           [17]
# 16    [ACRIN_6698_Patient_Cohorts_Clin]   [0]           [18]
# 17    [ACRIN_6698_Patient_Cohorts_Clin]   [0]           [19]
# 18    [ACRIN_6698_Patient_Cohorts_Clin]   [0]           [20]
# 19    [ACRIN_6698_Patient_Cohorts_Clin]   [0]           [21]
# 20    [ACRIN_6698_Patient_Cohorts_Clin]   [0]           [24]
# 21    [ACRIN_6698_Patient_Cohorts_Clin]   [0]           [25]
# 22    [ACRIN_6698_Patient_Cohorts_Clin]   [0]           [26]
# 23    [ACRIN_6698_Patient_Cohorts_Clin]   [0]           [27]
# 24    [ACRIN_6698_Patient_Cohorts_Clin]   [0]           [29]
# 1458  [ACRIN_6698_Patient_Cohorts_Clin]   [0]            [0]
# 1459  [ACRIN_6698_Patient_Cohorts_Clin]   [0]            [1]
# 1460  [ACRIN_6698_Patient_Cohorts_Clin]   [0]           [23]
# 1461  [ACRIN_6698_Patient_Cohorts_Clin]   [0]           [28]
# 3949  [ACRIN_6698_Patient_Cohorts_Clin]   [0]           [22]
# 9611                                 []    []             []
# 9692                                 []    []             []

# %%
ispy1_clinical_df[["collection_id", "table_name", "column", "column_label", "data_type", "values"]]
# Out:
#      collection_id                                         table_name  \
# 1661         ispy1  bigquery-public-data.idc_v11_clinical.ispy1_cl...
# 1662         ispy1  bigquery-public-data.idc_v11_clinical.ispy1_cl...
# 1663         ispy1  bigquery-public-data.idc_v11_clinical.ispy1_cl...
# 1664         ispy1  bigquery-public-data.idc_v11_clinical.ispy1_cl...
# 1665         ispy1  bigquery-public-data.idc_v11_clinical.ispy1_cl...
# 1666         ispy1  bigquery-public-data.idc_v11_clinical.ispy1_cl...
# 1667         ispy1  bigquery-public-data.idc_v11_clinical.ispy1_ou...
# 1668         ispy1  bigquery-public-data.idc_v11_clinical.ispy1_ou...
# 1669         ispy1  bigquery-public-data.idc_v11_clinical.ispy1_ou...
# 2316         ispy1  bigquery-public-data.idc_v11_clinical.ispy1_cl...
# 2317         ispy1  bigquery-public-data.idc_v11_clinical.ispy1_ou...
# 4053         ispy1  bigquery-public-data.idc_v11_clinical.ispy1_cl...
# 4054         ispy1  bigquery-public-data.idc_v11_clinical.ispy1_cl...
# 4055         ispy1  bigquery-public-data.idc_v11_clinical.ispy1_ou...
# 4459         ispy1  bigquery-public-data.idc_v11_clinical.ispy1_cl...
# 4460         ispy1  bigquery-public-data.idc_v11_clinical.ispy1_cl...
# 4461         ispy1  bigquery-public-data.idc_v11_clinical.ispy1_cl...
# 4462         ispy1  bigquery-public-data.idc_v11_clinical.ispy1_cl...
# 4463         ispy1  bigquery-public-data.idc_v11_clinical.ispy1_ou...
# 4464         ispy1  bigquery-public-data.idc_v11_clinical.ispy1_ou...
# 4777         ispy1  bigquery-public-data.idc_v11_clinical.ispy1_cl...
# 4778         ispy1  bigquery-public-data.idc_v11_clinical.ispy1_cl...
# 4985         ispy1  bigquery-public-data.idc_v11_clinical.ispy1_ou...
# 5165         ispy1  bigquery-public-data.idc_v11_clinical.ispy1_cl...
# 9628         ispy1  bigquery-public-data.idc_v11_clinical.ispy1_cl...
# 9629         ispy1  bigquery-public-data.idc_v11_clinical.ispy1_ou...
# 9818         ispy1  bigquery-public-data.idc_v11_clinical.ispy1_cl...
# 9819         ispy1  bigquery-public-data.idc_v11_clinical.ispy1_ou...
#
#                 column                     column_label data_type  \
# 1661         subjectid                        SUBJECTID    String
# 1662               age                              age   float64
# 1663   mri_ld_baseline                  MRI LD Baseline    String
# 1664     mri_ld_1_3dac                    MRI LD 1-3dAC    String
# 1665   mri_ld_interreg                  MRI LD InterReg    String
# 1666    mri_ld_presurg                   MRI LD PreSurg    String
# 1667         subjectid                        SUBJECTID    String
# 1668       survdtd2_tx                    survDtD2 (tx)     int64
# 1669               rfs                              RFS     int64
# 2316     dataextractdt                    DataExtractDt    String
# 2317     dataextractdt                    DataExtractDt    String
# 4053       bilateralca                      BilateralCa     int64
# 4054        laterality                       Laterality     int64
# 4055           rfs_ind                          rfs_ind     int64
# 4459             erpos                            ERpos    String
# 4460            pgrpos                           PgRpos    String
# 4461            hr_pos                           HR Pos    String
# 4462       her2mostpos                      Her2MostPos    String
# 4463             sstat                            sstat     int64
# 4464               pcr                              PCR    String
# 4777  hr_her2_category                 HR_HER2_CATEGORY    String
# 4778    hr_her2_status                   HR_HER2_STATUS    String
# 4985          rcbclass                         RCBClass    String
# 5165           race_id                          race_id     int64
# 9628      source_batch      idc_provenance_source_batch     int64
# 9629      source_batch      idc_provenance_source_batch     int64
# 9818  dicom_patient_id  idc_provenance_dicom_patient_id    String
# 9819  dicom_patient_id  idc_provenance_dicom_patient_id    String
#
#                                                  values
# 1661                                                 []
# 1662                                                 []
# 1663                                                 []
# 1664                                                 []
# 1665                                                 []
# 1666                                                 []
# 1667                                                 []
# 1668                                                 []
# 1669                                                 []
# 2316  [{'option_code': '2009-09-03T00:00:00.00000000...
# 2317  [{'option_code': '2009-09-03T00:00:00.00000000...
# 4053  [{'option_code': '0', 'option_description': No...
# 4054  [{'option_code': '1', 'option_description': No...
# 4055  [{'option_code': '0', 'option_description': No...
# 4459  [{'option_code': '1', 'option_description': No...
# 4460  [{'option_code': '0', 'option_description': No...
# 4461  [{'option_code': '1', 'option_description': No...
# 4462  [{'option_code': '0', 'option_description': No...
# 4463  [{'option_code': '7', 'option_description': No...
# 4464  [{'option_code': '0', 'option_description': No...
# 4777  [{'option_code': '1', 'option_description': No...
# 4778  [{'option_code': 'HER2pos', 'option_descriptio...
# 4985  [{'option_code': '2', 'option_description': No...
# 5165  [{'option_code': '0', 'option_description': No...
# 9628  [{'option_code': '0', 'option_description': No...
# 9629  [{'option_code': '0', 'option_description': No...
# 9818                                                 []
# 9819                                                 []

# %% [markdown]
# `table_name` gives us the location of the BigQuery table that contains the column described in the `column_metadata` row.
#
# Given the information available in the per-collection clinical data, we can proceed with selecting a subset of patients that meet the criteria of your interest. As an example, the following query will select all of the patients from the ISPY1 collections that had positive HER2 status.

# %%
# %%bigquery --project=idc-sandbox-000 ispy1_her2_status_patients
#
# SELECT DISTINCT(dicom_patient_id), hr_her2_status
# FROM bigquery-public-data.idc_v11_clinical.ispy1_clinical

# %%
ispy1_her2_status_patients
# Out:
#     dicom_patient_id hr_her2_status
# 0         ISPY1_1001   HRposHER2neg
# 1         ISPY1_1003   HRposHER2neg
# 2         ISPY1_1005   HRposHER2neg
# 3         ISPY1_1007   HRposHER2neg
# 4         ISPY1_1012   HRposHER2neg
# ..               ...            ...
# 216       ISPY1_1208      TripleNeg
# 217       ISPY1_1216      TripleNeg
# 218       ISPY1_1220      TripleNeg
# 219       ISPY1_1227      TripleNeg
# 220       ISPY1_1159           None
#
# [221 rows x 2 columns]

# %% [markdown]
# Extensive metadata is available for the CPTAC collections.

# %%
cptac_coad_clinical_df = column_metadata_df[column_metadata_df["collection_id"] == "cptac_coad"]

cptac_coad_clinical_df
# Out:
#      collection_id  case_col  \
# 1255    cptac_coad     False
# 1795    cptac_coad      True
# 1796    cptac_coad     False
# 1797    cptac_coad     False
# 1798    cptac_coad     False
# ...            ...       ...
# 4122    cptac_coad     False
# 4516    cptac_coad     False
# 5007    cptac_coad     False
# 9650    cptac_coad     False
# 9841    cptac_coad     False
#
#                                              table_name  \
# 1255  bigquery-public-data.idc_v11_clinical.cptac_co...
# 1795  bigquery-public-data.idc_v11_clinical.cptac_co...
# 1796  bigquery-public-data.idc_v11_clinical.cptac_co...
# 1797  bigquery-public-data.idc_v11_clinical.cptac_co...
# 1798  bigquery-public-data.idc_v11_clinical.cptac_co...
# ...                                                 ...
# 4122  bigquery-public-data.idc_v11_clinical.cptac_co...
# 4516  bigquery-public-data.idc_v11_clinical.cptac_co...
# 5007  bigquery-public-data.idc_v11_clinical.cptac_co...
# 9650  bigquery-public-data.idc_v11_clinical.cptac_co...
# 9841  bigquery-public-data.idc_v11_clinical.cptac_co...
#
#                            column                     column_label data_type  \
# 1255  diag__ajcc_pathologic_stage      diag__ajcc_pathologic_stage    STRING
# 1795                 submitter_id                     submitter_id    STRING
# 1796                      case_id                          case_id    STRING
# 1797         demo__demographic_id             demo__demographic_id    STRING
# 1798           diag__diagnosis_id               diag__diagnosis_id    STRING
# ...                           ...                              ...       ...
# 4122       diag__prior_malignancy           diag__prior_malignancy    STRING
# 4516              demo__ethnicity                  demo__ethnicity    STRING
# 5007                   demo__race                       demo__race    STRING
# 9650                 source_batch      idc_provenance_source_batch   INTEGER
# 9841             dicom_patient_id  idc_provenance_dicom_patient_id    STRING
#
#      original_column_headers  \
# 1255                      []
# 1795                      []
# 1796                      []
# 1797                      []
# 1798                      []
# ...                      ...
# 4122                      []
# 4516                      []
# 5007                      []
# 9650                      []
# 9841                      []
#
#                                                  values files sheet_names  \
# 1255  [{'option_code': 'Stage I', 'option_descriptio...    []          []
# 1795                                                 []    []          []
# 1796                                                 []    []          []
# 1797                                                 []    []          []
# 1798                                                 []    []          []
# ...                                                 ...   ...         ...
# 4122  [{'option_code': 'no', 'option_description': N...    []          []
# 4516  [{'option_code': 'hispanic or latino', 'option...    []          []
# 5007  [{'option_code': 'american indian or alaska na...    []          []
# 9650  [{'option_code': '0', 'option_description': No...    []          []
# 9841                                                 []    []          []
#
#      batch column_numbers
# 1255   [0]             []
# 1795   [0]             []
# 1796   [0]             []
# 1797   [0]             []
# 1798   [0]             []
# ...    ...            ...
# 4122   [0]             []
# 4516   [0]             []
# 5007   [0]             []
# 9650   [0]             []
# 9841   [0]             []
#
# [100 rows x 12 columns]

# %% [markdown]
# ## TODO: Exploring clinical data: Patient-focused exploration
#
# Sometime you may want to know whether specific patient has any clinical data available. One way to do this is to locate the collection that patient belongs to, and then check whether any of the clinical data tables (if any) that are available for that collection have that patient identifier.
#
# Alternatively, we can build a complete list of patients that have clinical data by performing a union on all of the `dicom_patient_id` columns across all of the clinical data tables, which is what we do in the next cell.

# %%
all_clinical_tables = column_metadata_df["table_name"].unique()
query = "with patients_unionized as (SELECT dicom_patient_id, collection_id FROM "+all_clinical_tables[0].replace("v11","current")
for clinical_table in all_clinical_tables[1:]:
  query = query+" UNION ALL SELECT dicom_patient_id, collection_id FROM "+clinical_table.replace("v11","current")

selection_query = query+") select distinct(dicom_patient_id) from patients_unionized"

print(selection_query)

selection_result = bq_client.query(selection_query)
patients_df = selection_result.result().to_dataframe()
patients = patients_df["dicom_patient_id"].unique()
# Out:
# with patients_unionized as (SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_6698_clinical UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_A0 UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_A1 UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_A3 UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_AA UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_AB UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_AC UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_AF UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_AG UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_BA UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_BQ UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_BR UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_CA UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_CJ UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_CK UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_E3 UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_FS UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_FT UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_HE UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_I1 UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_IC UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_IE UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_IM UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_IS UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_JS UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_JT UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_LP UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_PF UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_PH UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_PM UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_PO UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_PR UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_RT UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_SB UNION ALL SELECT dicom_patient_id, col ...
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# <ipython-input-7-a726c9d13647> in <module>
#       9
#      10 selection_result = bq_client.query(selection_query)
# ---> 11 patients_df = selection_result.result().to_dataframe()
#      12 patients = patients_df["dicom_patient_id"].unique()
#
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/job.py in result(self, timeout, page_size, retry, max_results)
#    2972         """
#    2973         try:
# -> 2974             super(QueryJob, self).result(timeout=timeout)
#    2975
#    2976             # Return an iterator instead of returning the job.
#
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/job.py in result(self, timeout, retry)
#     766             self._begin(retry=retry)
#     767         # TODO: modify PollingFuture so it can pass a retry argument to done().
# --> 768         return super(_AsyncJob, self).result(timeout=timeout)
#     769
#     770     def cancelled(self):
#
# /usr/local/lib/python3.7/dist-packages/google/api_core/future/polling.py in result(self, timeout, retry)
#     133             # pylint: disable=raising-bad-type
#     134             # Pylint doesn't recognize that this is valid in this case.
# --> 135             raise self._exception
#     136
#     137         return self._result
#
# BadRequest: 400 Unrecognized name: collection_id at [1:54]
#
# (job ID: 593ac626-6112-4a52-969c-f629d6503b85)
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
#
#     |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |  ...
#    1:with patients_unionized as (SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_6698_clinical UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_A0 UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_A1 UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_A3 UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_AA UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_AB UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_AC UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_AF UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_AG UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_BA UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_BQ UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_current_clinical.acrin_flt_breast_BR UNION ALL SELECT dicom_patient_id, collection_id FROM bigquery-public-data.idc_cur...
#     |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |  ...
