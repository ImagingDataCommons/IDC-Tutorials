# %% [markdown]
# <a href="https://colab.research.google.com/github/ImagingDataCommons/IDC-Tutorials/blob/master/notebooks/getting_started/exploring_clinical_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Working with IDC clinical data without BigQuery
#
# In this notebook we cover the basics of how you can access and search IDC clinical data without depending on Google BigQuery.
#
# In addition to maintaining clinical data in Google BigQuery tables, we also export those in Parquet format into a public cloud-based storage bucket. Those files are free to download, and are rather small (as of IDC v18, less than 65MB altogether).
#
# Once downloaded, you can search the content using Pandas sytax of SQL.
#
# This brief notebook will guide you through the steps of the above.
#
# If you have never worked with IDC before, we recommend you first complete the getting started tutorial [here](https://github.com/ImagingDataCommons/IDC-Tutorials/blob/master/notebooks/getting_started/part2_searching_basics.ipynb).
#
# ---
# Initial version: Jul 2024
#
# Updated: Sep 2024

# %% [markdown]
# ## Prerequisites
#
# The only prerequisite is [`idc-index`](https://github.com/ImagingDataCommons/idc-index) - python package that contains various utilities to simplify access to IDC data. As part of this package installation, you will get several other packages that we will use later:
# * `s5cmd` for very efficient download of data from cloud buckets using S3 API
# * `pandas` for dataframe operations
# * `duckdb` for querying pandas dataframes using SQL syntax

# %%
# %%capture
# !pip install --upgrade idc-index

# %% [markdown]
# ## Fetch clinical data index
#
# `idc-index` packages various tables with the key metadata. We refer to those as _indices_. The main index that supports API calls related to download and search is installed by default. To support search of the clinical data accompanying IDC images you will need the `clinical_index` table, which contains the list of all columns and all tables across all of the IDC collections that are available.

# %%
from idc_index import index

c = index.IDCClient()

c.fetch_index('clinical_index')

print('Columns avaialable in clinical_index:\n'+'\n'.join(c.clinical_index.keys()))
# Out:
# Columns avaialable in clinical_index:
# collection_id
# table_name
# short_table_name
# column
# column_label

# %% [markdown]
# # Find all clinical metadata available for the specific collection
#
# A common use case is to find all clinical data available for a specific IDC collection.
#
# The key columns of this dataframe are:
# * `collection_id`: which collection given metadata attribute corresponds to
# * `table_name`: the name of the table where this metadata attribute is located
# * `column`: name of the column (attribute)
#
# Depending on the specific attribute and how it was provided/documented by the submitter, you may find more information about it in the `column_label` column.
#
# Let's assume we are interested in the clinical data accompanying the `rms_mutation_prediction` collection. We can select all clinical data attributes that are available for this collection as shown next.

# %%
# define the query that selects all rows where collection_id is 'rms_mutation_prediction'
# note that we can refer to clinical_index table in the query
query = """
SELECT *
FROM clinical_index
WHERE collection_id = 'rms_mutation_prediction'
"""

# execute the query
matching_items = c.sql_query(query)

# %%
matching_items
# Out:
#               collection_id  \
# 0   rms_mutation_prediction
# 1   rms_mutation_prediction
# 2   rms_mutation_prediction
# 3   rms_mutation_prediction
# 4   rms_mutation_prediction
# 5   rms_mutation_prediction
# 6   rms_mutation_prediction
# 7   rms_mutation_prediction
# 8   rms_mutation_prediction
# 9   rms_mutation_prediction
# 10  rms_mutation_prediction
# 11  rms_mutation_prediction
# 12  rms_mutation_prediction
# 13  rms_mutation_prediction
# 14  rms_mutation_prediction
# 15  rms_mutation_prediction
# 16  rms_mutation_prediction
# 17  rms_mutation_prediction
# 18  rms_mutation_prediction
# 19  rms_mutation_prediction
# 20  rms_mutation_prediction
# 21  rms_mutation_prediction
# 22  rms_mutation_prediction
# 23  rms_mutation_prediction
# 24  rms_mutation_prediction
# 25  rms_mutation_prediction
# 26  rms_mutation_prediction
# 27  rms_mutation_prediction
# 28  rms_mutation_prediction
# 29  rms_mutation_prediction
# 30  rms_mutation_prediction
# 31  rms_mutation_prediction
# 32  rms_mutation_prediction
# 33  rms_mutation_prediction
# 34  rms_mutation_prediction
# 35  rms_mutation_prediction
# 36  rms_mutation_prediction
# 37  rms_mutation_prediction
# 38  rms_mutation_prediction
#
#                                            table_name  \
# 0   bigquery-public-data.idc_v19_clinical.rms_muta...
# 1   bigquery-public-data.idc_v19_clinical.rms_muta...
# 2   bigquery-public-data.idc_v19_clinical.rms_muta...
# 3   bigquery-public-data.idc_v19_clinical.rms_muta...
# 4   bigquery-public-data.idc_v19_clinical.rms_muta...
# 5   bigquery-public-data.idc_v19_clinical.rms_muta...
# 6   bigquery-public-data.idc_v19_clinical.rms_muta...
# 7   bigquery-public-data.idc_v19_clinical.rms_muta...
# 8   bigquery-public-data.idc_v19_clinical.rms_muta...
# 9   bigquery-public-data.idc_v19_clinical.rms_muta...
# 10  bigquery-public-data.idc_v19_clinical.rms_muta...
# 11  bigquery-public-data.idc_v19_clinical.rms_muta...
# 12  bigquery-public-data.idc_v19_clinical.rms_muta...
# 13  bigquery-public-data.idc_v19_clinical.rms_muta...
# 14  bigquery-public-data.idc_v19_clinical.rms_muta...
# 15  bigquery-public-data.idc_v19_clinical.rms_muta...
# 16  bigquery-public-data.idc_v19_clinical.rms_muta...
# 17  bigquery-public-data.idc_v19_clinical.rms_muta...
# 18  bigquery-public-data.idc_v19_clinical.rms_muta...
# 19  bigquery-public-data.idc_v19_clinical.rms_muta...
# 20  bigquery-public-data.idc_v19_clinical.rms_muta...
# 21  bigquery-public-data.idc_v19_clinical.rms_muta...
# 22  bigquery-public-data.idc_v19_clinical.rms_muta...
# 23  bigquery-public-data.idc_v19_clinical.rms_muta...
# 24  bigquery-public-data.idc_v19_clinical.rms_muta...
# 25  bigquery-public-data.idc_v19_clinical.rms_muta...
# 26  bigquery-public-data.idc_v19_clinical.rms_muta...
# 27  bigquery-public-data.idc_v19_clinical.rms_muta...
# 28  bigquery-public-data.idc_v19_clinical.rms_muta...
# 29  bigquery-public-data.idc_v19_clinical.rms_muta...
# 30  bigquery-public-data.idc_v19_clinical.rms_muta...
# 31  bigquery-public-data.idc_v19_clinical.rms_muta...
# 32  bigquery-public-data.idc_v19_clinical.rms_muta...
# 33  bigquery-public-data.idc_v19_clinical.rms_muta...
# 34  bigquery-public-data.idc_v19_clinical.rms_muta...
# 35  bigquery-public-data.idc_v19_clinical.rms_muta...
# 36  bigquery-public-data.idc_v19_clinical.rms_muta...
# 37  bigquery-public-data.idc_v19_clinical.rms_muta...
# 38  bigquery-public-data.idc_v19_clinical.rms_muta...
#
#                         short_table_name                              column  \
# 0   rms_mutation_prediction_demographics                        source_batch
# 1   rms_mutation_prediction_demographics                                race
# 2   rms_mutation_prediction_demographics                              gender
# 3   rms_mutation_prediction_demographics                    dicom_patient_id
# 4   rms_mutation_prediction_demographics                      participant_id
# 5      rms_mutation_prediction_diagnosis                        source_batch
# 6      rms_mutation_prediction_diagnosis                        diagnosis_id
# 7      rms_mutation_prediction_diagnosis                        disease_type
# 8      rms_mutation_prediction_diagnosis                   primary_diagnosis
# 9      rms_mutation_prediction_diagnosis  primary_diagnosis_reference_source
# 10     rms_mutation_prediction_diagnosis             metastasis_at_diagnosis
# 11     rms_mutation_prediction_diagnosis                               stage
# 12     rms_mutation_prediction_diagnosis           last_known_disease_status
# 13     rms_mutation_prediction_diagnosis   days_to_last_known_disease_status
# 14     rms_mutation_prediction_diagnosis           tissue_or_organ_of_origin
# 15     rms_mutation_prediction_diagnosis           progression_or_recurrence
# 16     rms_mutation_prediction_diagnosis         site_of_resection_or_biopsy
# 17     rms_mutation_prediction_diagnosis                    dicom_patient_id
# 18     rms_mutation_prediction_diagnosis           participantparticipant_id
# 19     rms_mutation_prediction_diagnosis                        primary_site
# 20     rms_mutation_prediction_diagnosis                  days_to_recurrence
# 21     rms_mutation_prediction_diagnosis               days_to_last_followup
# 22     rms_mutation_prediction_diagnosis                    age_at_diagnosis
# 23        rms_mutation_prediction_sample                        source_batch
# 24        rms_mutation_prediction_sample                         sample_type
# 25        rms_mutation_prediction_sample         histological_classification
# 26        rms_mutation_prediction_sample                         tumor_grade
# 27        rms_mutation_prediction_sample              tumor_stage_clinical_t
# 28        rms_mutation_prediction_sample              tumor_stage_clinical_n
# 29        rms_mutation_prediction_sample              tumor_stage_clinical_m
# 30        rms_mutation_prediction_sample                    tumor_morphology
# 31        rms_mutation_prediction_sample                tumor_incidence_type
# 32        rms_mutation_prediction_sample                  sample_description
# 33        rms_mutation_prediction_sample                 sample_tumor_status
# 34        rms_mutation_prediction_sample                    dicom_patient_id
# 35        rms_mutation_prediction_sample           participantparticipant_id
# 36        rms_mutation_prediction_sample                           sample_id
# 37        rms_mutation_prediction_sample                sample_anatomic_site
# 38        rms_mutation_prediction_sample       participant_age_at_collection
#
#                           column_label
# 0          idc_provenance_source_batch
# 1                                 race
# 2                               gender
# 3      idc_provenance_dicom_patient_id
# 4                       participant_id
# 5          idc_provenance_source_batch
# 6                         diagnosis_id
# 7                         disease_type
# 8                    primary_diagnosis
# 9   primary_diagnosis_reference_source
# 10             Metastasis_at_diagnosis
# 11                               Stage
# 12           last_known_disease_status
# 13   days_to_last_known_disease_status
# 14           tissue_or_organ_of_origin
# 15           progression_or_recurrence
# 16         site_of_resection_or_biopsy
# 17     idc_provenance_dicom_patient_id
# 18          participant.participant_id
# 19                        primary_site
# 20                  days_to_recurrence
# 21               days_to_last_followup
# 22                    age_at_diagnosis
# 23         idc_provenance_source_batch
# 24                         sample_type
# 25         Histological_Classification
# 26                         tumor_grade
# 27              tumor_stage_clinical_t
# 28              tumor_stage_clinical_n
# 29              tumor_stage_clinical_m
# 30                    tumor_morphology
# 31                tumor_incidence_type
# 32                  sample_description
# 33                 sample_tumor_status
# 34     idc_provenance_dicom_patient_id
# 35          participant.participant_id
# 36                           sample_id
# 37                sample_anatomic_site
# 38       participant_age_at_collection

# %% [markdown]
# # Downloading the tables with clinical data
#
# The `table` column in `clinical_index` refers to the actual tables that contain the listed columns. Those tables are relatively small, and are maintained by IDC both in Google BigQuery and in Parquet files available for download from a public AWS bucket.
#
# Since the total size of those tables is small, it is easiest to download all of them (but of course you can also download just the individual ones).

# %%
# %%capture
idc_version = c.get_idc_version()

clinical_data_aws_path = f"s3://idc-open-metadata/bigquery_export/idc_{idc_version}_clinical/*"

# !mkdir -p idc_clinical_data
# !s5cmd --no-sign-request cp {clinical_data_aws_path} ./idc_clinical_data

# %% [markdown]
# # Access table that contains specific metadata attribute
#
# Let's assume we are interested in the `tumor_grade` attribute (row 13 in the table above). From the above, column `table_name` is telling us that it is contained in the table `bigquery-public-data.idc_v18_clinical.rms_mutation_prediction_sample`. The table name is the fully resolved name in BigQuery. For locating this table as downloaded, we need just the last component of the name: `rms_mutation_prediction_sample`.
#
# We can access and search this table next.

# %%
import pandas as pd

a_table_df = pd.read_parquet('./idc_clinical_data/rms_mutation_prediction_sample')

a_table_df
# Out:
#     dicom_patient_id  source_batch participantparticipant_id sample_id  \
# 0            RMS2325             0                   RMS2325    PAWDLM
# 1            RMS2124             0                   RMS2124    PATMDI
# 2            RMS2137             0                   RMS2137    PATVPL
# 3            RMS2140             0                   RMS2140    PATYYW
# 4            RMS2145             0                   RMS2145    PAUKHP
# ..               ...           ...                       ...       ...
# 398          RMS2374             0                   RMS2374    PAUPVA
# 399          RMS2352             0                   RMS2352    PASGZC
# 400          RMS2205             0                   RMS2205    PAMSJL
# 401          RMS2267             0                   RMS2267    PALWAA
# 402          RMS2459             0                   RMS2459    PAPRFM
#
#     sample_type   sample_anatomic_site  participant_age_at_collection  \
# 0         Tumor                    Leg                          44.56
# 1         Tumor                                                  0.90
# 2         Tumor                                                  0.83
# 3         Tumor                                                  1.07
# 4         Tumor                                                  2.72
# ..          ...                    ...                            ...
# 398       Tumor   Paratesticular, left                           2.46
# 399       Tumor  Paratesticular, right                           0.68
# 400       Tumor                 Pelvis                           2.76
# 401       Tumor   Soft tissue, abdomen                          17.96
# 402       Tumor               Prostate                           8.39
#
#                            histological_classification tumor_grade  \
# 0
# 1                                             BOTRYOID
# 2                                             BOTRYOID
# 3                                             BOTRYOID
# 4                                             BOTRYOID
# ..                                                 ...         ...
# 398                      SPINDLE CELL RHABDOMYOSARCOMA
# 399                      SPINDLE CELL RHABDOMYOSARCOMA
# 400      MIXED ALVEOLAR AND EMBRYONAL RHABDOMYOSARCOMA
# 401      MIXED ALVEOLAR AND EMBRYONAL RHABDOMYOSARCOMA
# 402  EMBRYONAL RHABDOMYOSARCOMA WITH DIFFUSE ANAPLASIA
#
#     tumor_stage_clinical_t tumor_stage_clinical_n tumor_stage_clinical_m  \
# 0
# 1
# 2
# 3
# 4
# ..                     ...                    ...                    ...
# 398
# 399
# 400
# 401
# 402
#
#     tumor_morphology tumor_incidence_type sample_description  \
# 0
# 1
# 2
# 3
# 4
# ..               ...                  ...                ...
# 398
# 399
# 400
# 401
# 402
#
#     sample_tumor_status
# 0                 Tumor
# 1                 Tumor
# 2                 Tumor
# 3                 Tumor
# 4                 Tumor
# ..                  ...
# 398               Tumor
# 399               Tumor
# 400               Tumor
# 401               Tumor
# 402               Tumor
#
# [403 rows x 16 columns]

# %% [markdown]
# Now that this table is loaded, you can search it as you would any pandas dataframe (or you can use SQL with duckdb, as shown earlier!).
#
# Note that the `dicom_patient_id` column, which you will find in **every** clinical data table, can be used to link clinical metadata attributes to the DICOM image metadata!

# %% [markdown]
# ## Summary
#
# We hope you enjoyed this tutorial! If something didn't work as expected, if you have any feedback or suggestions of what should be added to this tutorial, please contact IDC support by sending email to support@canceridc.dev or posting your question on [IDC User forum](https://discourse.canceridc.dev).

# %% [markdown]
# ## Acknowledgments
#
# Imaging Data Commons has been funded in whole or in part with Federal funds from the National Cancer Institute, National Institutes of Health, under Task Order No. HHSN26110071 under Contract No. HHSN261201500003l.
#
# If you use IDC in your research, please cite the following publication:
#
# > Fedorov, A., Longabaugh, W. J. R., Pot, D., Clunie, D. A., Pieper, S. D., Gibbs, D. L., Bridge, C., Herrmann, M. D., Homeyer, A., Lewis, R., Aerts, H. J. W., Krishnaswamy, D., Thiriveedhi, V. K., Ciausu, C., Schacherer, D. P., Bontempi, D., Pihl, T., Wagner, U., Farahani, K., Kim, E. & Kikinis, R. _National Cancer Institute Imaging Data Commons: Toward Transparency, Reproducibility, and Scalability in Imaging Artificial Intelligence_. RadioGraphics (2023). https://doi.org/10.1148/rg.230180
